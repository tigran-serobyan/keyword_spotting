# %% [markdown]
# <a href="https://colab.research.google.com/github/tigran-serobyan/keyword_spotting/blob/main/Keyword_spotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Keyword spotting

# %% [markdown]
# ## Importing libraries

# %%
# !pip install numpy matplotlib scipy tensorflow
# Out:
# Requirement already satisfied: numpy in /home/narek/miniconda3/lib/python3.9/site-packages (1.24.0)
# Requirement already satisfied: matplotlib in /home/narek/miniconda3/lib/python3.9/site-packages (3.6.2)
# Requirement already satisfied: scipy in /home/narek/miniconda3/lib/python3.9/site-packages (1.9.3)
# Collecting tensorflow
#   Using cached tensorflow-2.11.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588.3 MB)
# Requirement already satisfied: pillow>=6.2.0 in /home/narek/miniconda3/lib/python3.9/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/narek/miniconda3/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/narek/miniconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/narek/miniconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/narek/miniconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/narek/miniconda3/lib/python3.9/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in /home/narek/miniconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/narek/miniconda3/lib/python3.9/site-packages (from matplotlib) (4.38.0)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.29.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 57 kB/s  eta 0:00:01
# Collecting tensorboard<2.12,>=2.11
#   Using cached tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting keras<2.12,>=2.11.0
#   Using cached keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.51.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Using cached protobuf-3.19.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Requirement already satisfied: six>=1.12.0 in /home/narek/miniconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Collecting libclang>=13.0.0
#   Using cached libclang-14.0.6-py2.py3-none-manylinux2010_x86_64.whl (14.1 MB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-22.12.6-py2.py3-none-any.whl (26 kB)
# Collecting typing-extensions>=3.6.6
#   Using cached typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-1.14.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.1.1-py3-none-any.whl (6.2 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.3.0-py3-none-any.whl (124 kB)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Using cached tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
# Requirement already satisfied: setuptools in /home/narek/miniconda3/lib/python3.9/site-packages (from tensorflow) (61.2.0)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.7.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/narek/miniconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting werkzeug>=1.0.1
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.15.0-py2.py3-none-any.whl (177 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/narek/miniconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.27.1)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/narek/miniconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /home/narek/miniconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.11.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/narek/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/narek/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/narek/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/narek/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.0.4)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/narek/miniconda3/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.1)
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, google-auth, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed absl-py-1.3.0 astunparse-1.6.3 cachetools-5.2.0 flatbuffers-22.12.6 gast-0.4.0 google-auth-2.15.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.51.1 h5py-3.7.0 keras-2.11.0 libclang-14.0.6 markdown-3.4.1 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.11.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-io-gcs-filesystem-0.29.0 termcolor-2.1.1 typing-extensions-4.4.0 werkzeug-2.2.2 wrapt-1.14.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from loader import *
# Out:
# 2022-12-20 20:21:09.322462: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-20 20:21:09.820948: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib/cuda/include:/usr/lib/cuda/lib64:
# 2022-12-20 20:21:09.821007: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-20 20:21:11.781772: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib/cuda/include:/usr/lib/cuda/lib64:
# 2022-12-20 20:21:11.782144: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib/cuda/include:/usr/lib/cuda/lib64:
# 2022-12-20 20:21:11.782156: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Loading Data

# %%
git_loader("https://github.com/Jakobovski/free-spoken-digit-dataset.git")
# Out:
# Cloning into 'free-spoken-digit-dataset'...

# %% [markdown]
# ### Processing data

# %%
get_audios("free-spoken-digit-dataset/recordings")
classify_audios_by_spectogram("free-spoken-digit-dataset/recordings")
delete_folder("free-spoken-digit-dataset")

# %%
SIZE = 256
BATCH_SIZE = 32
channels = 3
kernel = 4
stride = 1
pool = 2
output_dir = '/working'

train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
                                             batch_size=BATCH_SIZE,
                                             validation_split=0.2,
                                             directory=output_dir,
                                             shuffle=True,
                                             color_mode='rgb',
                                             image_size=(SIZE, SIZE),
                                             subset="training",
                                             seed=0);

valid_dataset = tf.keras.preprocessing.image_dataset_from_directory(
                                             batch_size=BATCH_SIZE,
                                             validation_split=0.2,
                                             directory=output_dir,
                                             shuffle=True,
                                             color_mode='rgb',
                                             image_size=(SIZE, SIZE),
                                             subset="validation",
                                             seed=0);
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[12], line 9
#       6 pool = 2
#       7 output_dir = '/working'
# ----> 9 train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
#      10                                              batch_size=BATCH_SIZE,
#      11                                              validation_split=0.2,
#      12                                              directory=output_dir,
#      13                                              shuffle=True,
#      14                                              color_mode='rgb',
#      15                                              image_size=(SIZE, SIZE),
#      16                                              subset="training",
#      17                                              seed=0);
#      19 valid_dataset = tf.keras.preprocessing.image_dataset_from_directory(
#      20                                              batch_size=BATCH_SIZE,
#      21                                              validation_split=0.2,
#    (...)
#      26                                              subset="validation",
#      27                                              seed=0);
#
# File ~/miniconda3/lib/python3.9/site-packages/keras/utils/image_dataset.py:207, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, **kwargs)
#     205 if seed is None:
#     206     seed = np.random.randint(1e6)
# --> 207 image_paths, labels, class_names = dataset_utils.index_directory(
#     208     directory,
#     209     labels,
#     210     formats=ALLOWLIST_FORMATS,
#     211     class_names=class_names,
#     212     shuffle=shuffle,
#     213     seed=seed,
#     214     follow_links=follow_links,
#     215 )
#     217 if label_mode == "binary" and len(class_names) != 2:
#     218     raise ValueError(
#     219         'When passing `label_mode="binary"`, there must be exactly 2 '
#     220         f"class_names. Received: class_names={class_names}"
#     221     )
#
# File ~/miniconda3/lib/python3.9/site-packages/keras/utils/dataset_utils.py:534, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links)
#     532 else:
#     533     subdirs = []
# --> 534     for subdir in sorted(tf.io.gfile.listdir(directory)):
#     535         if tf.io.gfile.isdir(tf.io.gfile.join(directory, subdir)):
#     536             if subdir.endswith("/"):
#
# File ~/miniconda3/lib/python3.9/site-packages/tensorflow/python/lib/io/file_io.py:768, in list_directory_v2(path)
#     753 """Returns a list of entries contained within a directory.
#     754
#     755 The list is in arbitrary order. It does not contain the special entries "."
#    (...)
#     765   errors.NotFoundError if directory doesn't exist
#     766 """
#     767 if not is_directory(path):
# --> 768   raise errors.NotFoundError(
#     769       node_def=None,
#     770       op=None,
#     771       message="Could not find directory {}".format(path))
#     773 # Convert each element to string, since the return values of the
#     774 # vector of string should be interpreted as strings, not bytes.
#     775 return [
#     776     compat.as_str_any(filename)
#     777     for filename in _pywrap_file_io.GetChildren(compat.path_to_bytes(path))
#     778 ]
#
# NotFoundError: Could not find directory /working

# %%
plt.figure(figsize=(12, 12));
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1);
        plt.imshow(images[i].numpy().astype("uint8"));
        plt.title(int(labels[i]));
        plt.axis("off");
plt.show();

# %%
class_names = train_dataset.class_names
num_classes = len(class_names)
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = valid_dataset.cache().prefetch(buffer_size=AUTOTUNE)

model = Sequential([
    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(SIZE, SIZE, channels)),
    layers.Conv2D(16, kernel, stride, activation='relu'),
    layers.MaxPool2D(pool),
    layers.Conv2D(32, kernel, stride, activation='relu'),
    layers.MaxPool2D(pool),
    layers.Conv2D(64, kernel, stride, activation='relu'),
    layers.MaxPool2D(pool),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes)
])
model.summary()

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)
model.compile(optimizer='adam', 
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
                  metrics=['accuracy'])

# %%
epochs = 15
history = model.fit(
    train_ds, epochs=epochs, callbacks=model_checkpoint_callback, validation_data=val_ds,
);
